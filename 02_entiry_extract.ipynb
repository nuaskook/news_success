# %% [markdown]
# # 02_entiry-extract
# * entity extraction from news description using trasnformer Davlan/xlm-roberta-base-ner-hrl

# %% [markdown]
# ### install extra library

# %%
# !pip install transformers torch
# !pip install sentencepiece
# Out:
# Collecting transformers
#   Using cached transformers-4.23.1-py3-none-any.whl (5.3 MB)
# Collecting torch
#   Downloading torch-1.13.0-cp310-cp310-manylinux1_x86_64.whl (890.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.1/890.1 MB 1.0 MB/s eta 0:00:0000:0100:05
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 5.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0)
# Collecting filelock
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.22.4)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 5.4 MB/s eta 0:00:00
# Collecting regex!=2019.12.17
#   Downloading regex-2022.10.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (770 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 5.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.64.0)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.6 MB/s eta 0:00:0000:0100:03
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.6 MB/s eta 0:00:0000:0100:02
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 3.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 606.8 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.3.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (63.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.11)
# Installing collected packages: tokenizers, regex, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, filelock, nvidia-cudnn-cu11, huggingface-hub, transformers, torch
# Successfully installed filelock-3.8.0 huggingface-hub-0.10.1 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 regex-2022.10.31 tokenizers-0.13.1 torch-1.13.0 transformers-4.23.1
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.97-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97

# %% [markdown]
# ### read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 54
dir_process_id = 55

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='news1.json'))
meta
# Out:
# {'owner': 'natthakan',
#  'human_size': '40.61 KB',
#  'name': 'news1.json',
#  'description': 'file news1.json',
#  'directory': 54,
#  'path': 'natthakan/DSI310-05/rawData/news1.json'}

# %%
data = json.load(fp)
data
# Out:
# [{'title': 'นายกฯ ขอให้ทุกคนรักชาติ มีศรัทธาในการทำงาน เกษตรกรก็ประสบความสำเร็จในอาชีพได้',
#   'detail': 'วันนี้ (3 ตุลาคม) \u202aเวลา 13.30 น. ณ โรงแรมมิราเคิล แกรนด์ กรุงเทพฯ พล.อ. ประยุทธ์ จันทร์โอชา นายกรัฐมนตรี และรัฐมนตรีว่าการกระทรวงกลาโหม เป็นประธานมอบนโยบายแก่สภาเกษตรกรแห่งชาติ ในโอกาสจัดประชุมสภาเกษตรกรแห่งชาติ ปีงบประมาณ 2563 พร้อมด้วย สมคิด จาตุศรีพิทักษ์ รองนายกรัฐมนตรี เฉลิมชัย ศรีอ่อน รัฐมนตรีว่าการกระทรวงเกษตรและสหกรณ์ สมาชิกสภาเกษตรกรแห่งชา...',
#   'DATE': '3-10-2019'},
#  {'title': '7 Things We Love About Hailey Bieber ผู้หญิงที่เป็นมากกว่าแค่ภรรยาศิลปินชื่อดัง',
#   'detail': 'ใครที่ติดตามข่าวสารและป๊อปคัลเจอร์อยู่เสมอจะต้องรู้จักชื่อของ Hailey Bieber (เฮลีย์ บีเบอร์) นางแบบ นักธุริจ และภรรยาสาวของศิลปินแห่งยุคอย่าง Justin Bieber (จัสติน บีเบอร์) แม้ภายนอกเธอจะดูเก๋โก้และเป็นแฟชั่นไอคอนให้กับเจนใหม่ แต่จริงๆ แล้วที่หลายคนหลงเสน่ห์เธอกลับเป็นเพราะบุคลิคที่เข้าถึงได้และเป็นกันเองของเธอต่างหาก\n\xa0\nนอกจากปกนิตยสารแล...',
#   'DATE': '23-10-2022'},
#  {'title': 'POP TIP: เคล็ดลับการประสบความสำเร็จของ Jackson Wang คือทำในสิ่งที่ตัวเองรัก',
#   'detail': 'เคล็ดลับการทำงานอยู่บ้านให้เหนื่อยน้อยลง มีความสุขมากขึ้น\n\xa0\n\xa0\nคุณกำลังรู้สึกว่าการ Work from Home ยิ่งนาน คุณยิ่งเหนื่อยและเครียดมากกว่าเดิมหรือเปล่า ไหนจะต้องคอยอัปเดตงานผ่านการประชุมออนไลน์ที่กินเวลายาวเหยียด (บางครั้งไม่ได้ประเด็นสำคัญสักเท่าไร) บางคนก็รู้สึกเหมือนสุขภาพแย่ลง งานที่ต้องรับผิดชอบแม้จะเป็นงานเดิม แต่ปร...',
#   'DATE': '10-08-2021'},
#  {'title': 'ยืนงงในดงผู้ดีไปกับ Mine ซีรีส์เกาหลีเจาะลึก ‘ความเจ๊บ ความฉ่ำ’ ในชีวิตคนรวย',
#   'detail': '“พวกเขาไม่มีความพึงพอใจ ไม่ว่ากินมากเท่าไรก็ยังโหยหิวอยู่ ความละโมบที่ไม่สิ้นสุดยิ่งทำให้พวกเขานั้นตกนรกน่ะสิ”\xa0\n\xa0\nคำกล่าวของแม่ชีเอ็มม่า ตัวละครผู้กุมความลับสำคัญในซีรีส์เกาหลีเรื่อง Mine น่าจะบอกใบ้เนื้อหาของซีรีส์เรื่องนี้ได้เป็นอย่างดี ถ้าลองสังเกตดูในระยะหลังๆ เราจะได้ดูคอนเทนต์เกี่ยวกับชีวิตคนรวยอยู่เรื่อยๆ เพราะมันเป็นที่นิยมใ...',
#   'DATE': '14-05-2021'},
#  {'title': 'Park Nae Joo Celebrity Hair Stylist, CEO of Beauty Salon Bit & Boot ผู้อยู่เบื้องหลังทรงผมสุดเท่ของหนุ่มๆ วง BTS และ EXO',
#   'detail': 'BTS จัดว่าเป็นวงบอยแบนด์ที่มีส่วนสำคัญในการช่วยขับเคลื่อนวงการ K-Pop ให้แผ่ขยายความนิยมออกไปทั่วโลก ผลงานของพวกเขาทำให้เหล่า อาร์มี่ ต่างรู้สึกมีความสุขที่เห็นพวกเขาเติบโตทั้งผลงาน ความคิด รวมถึงลุคใหม่ๆ ที่สลับสับเปลี่ยนไปอย่างน่าสนใจในทุกๆ อัลบั้ม แต่เคยสงสัยไหมว่าใครกันนะ คือผู้ที่อยู่เบื้องหลังลุคทรงผมหล่อเท่ของพวกเขามาโดยตลอด เรียกว่าเป็นดั่งช...',
#   'DATE': '8-03-2021'},
#  {'title': 'ซูเปอร์โบวล์ ครั้งที่ 55 ศึกระหว่าง เบรดี กับ มาโฮมส์ ผู้ท้าชิงบัลลังก์ระดับตำนาน',
#   'detail': 'แพทริก มาโฮมส์ เพิ่งอายุแค่ 6 ขวบ สมัย นิวอิงแลนด์ เพเทรียตส์ พลิกล็อกเชือด เซนต์หลุยส์ แรมส์ 20-17 คว้าแชมป์ซูเปอร์โบวล์ ครั้ง 36\n\xa0\nจากนั้นเขายังได้เห็น ทอม เบรดี นำทัพ เพเทรียตส์ เข้าแข่งบนเวทีใหญ่สุดของลีกอีกหลายต่อหลายครั้ง\n\xa0\nไม่น่าแปลกใจ ถ้าจะเห็นมาโฮมส์กล่าวติดตลก ราวกับเบรดีแข่งซูเปอร์โบวล์มาชั่วกัปชั่วกัลป์\n\xa0\n...',
#   'DATE': '3-02-2021'},
#  {'title': '‘หัวแล่น แม่นไม่ลืม’ เทคนิคดูแลเซลล์สมองให้สดใหม่ เพิ่มความจำได้ไม่จำกัด [Advertorial]',
#   'detail': 'สมองกับความจำเกี่ยวพันกันอย่างไร แล้วทำไมการใช้สมองหนักเกินไปอาจส่งผลกระทบระยะยาวต่อความจำ\nโดยเฉพาะสมองของคนวัยทำงานที่ต้องคิดและเค้นไอเดียอยู่ตลอดเวลา ภาระหนักจึงไปตกอยู่ที่สมองส่วน Prefrontal cortex ซึ่งเป็นสมองที่เกี่ยวข้องกับกระบวนการคิดและการจำ ยิ่งคิดเยอะ คิดหนัก คิดนาน สมองสะสมความเหนื่อยล้าทุกวัน ประสิทธิภาพสมองเริ่มถดถอย ทำงานได้ไม่เต็...',
#   'DATE': '7-02-2020'},
#  {'title': 'เอสซีจี เมืองทองฯ – ชิมิสุ เอส-พัลส์ ร่วมแถลงข่าวเซ็นสัญญา ‘มุ้ย ธีรศิลป์’ ย้ายค้าแข้งศึกเจลีก 2020',
#   'detail': 'เอสซีจี เมืองทอง ยูไนเต็ด ทำการแถลงข่าวปล่อยตัว มุ้ย-ธีรศิลป์ แดงดา กองหน้าตัวเก่ง วัย 31 ปี ย้ายไปร่วมทีมชิมิสุ เอส-พัลส์ สโมสรดังในศึกเจลีก ญี่ปุ่น ฤดูกาล 2020 อย่างเป็นทางการด้วยสัญญา 2 ปี โดยจะสวมเสื้อหมายเลข 23\xa0\n\xa0\nรณฤทธิ์ ซื่อวาจา ผู้อำนวยการสโมสรเอสซีจี เมืองทอง ยูไนเต็ด กล่าวว่า “ถือเป็นความภาคภูมิใจกับการผจญภัยครั้งใหม่ของนั...',
#   'DATE': '5-02-2020'},
#  {'title': 'เปลี่ยน Mindset คนด้วยการสร้าง ‘ประสบการณ์ร่วม’ แบบไทยประกันชีวิต เจ้าแห่งหนังโฆษณาเรียกน้ำตา',
#   'detail': 'สร้างมายด์เซตใหม่ เสริมความแข็งแกร่งให้องค์กร ก้าวสู่ยุคแห่งการ Disrupt อย่างมั่นใจในแบบของ ไชย ไชยวรรณ กรรมการผู้จัดการใหญ่ บริษัท ไทยประกันชีวิต จำกัด (มหาชน)\n\xa0\nความท้าทายของผู้นำในยุคนี้ไม่ใช่การมีเทคโนโลยีล่าสุดอยู่ในมือหรือถือกลยุทธ์ล้ำสมัยไว้ในครอบครองอีกต่อไป แต่เป็นการผลักดันให้คนในองค์กรนับพันนับหมื่นคนปรับเปลี่ยนความคิด วิ่งตาม...',
#   'DATE': '23-01-2020'},
#  {'title': 'Kim Ji-Young, Born 1982 สัมภาษณ์ผู้กำกับ คิมโดยอน เบื้องหลังการทำงานกับ กงยู จองยูมี และภาพสะท้อนผู้หญิงในสังคมชายเป็นใหญ่',
#   'detail': '“ผมแทบไม่เคยร้องไห้ตอนที่อ่านบท แต่ผมก็ร้องไห้ตอนที่อ่านบท Kim Ji-Young, Born 1982 ไม่บ่อยนะครับที่ผมจะรู้สึกเหมือนอยู่ในเหตุการณ์ด้วยจริงๆ นั่นเพราะผมได้กลายเป็นตัวละครจองแดฮยอนและมีอารมณ์ร่วมมากๆ เมื่ออ่านบทจบผมรีบโทรศัพท์ไปหาแม่ เพราะอยากจะขอบคุณที่ท่านเลี้ยงผมมา” กงยู นักแสดงนำ ให้สัมภาษณ์ไว้ในวันแถลงข่าว สะท้อนให้เห็นความรู้สึกของเขา ตัวแทนผู้...',
#   'DATE': '23-12-2019'},
#  {'title': 'Jung Saem Mool แบรนด์ความงามจากแดนกิมจิ เปิดตัวครั้งแรกในไทย',
#   'detail': 'บรรยากาศยามบ่ายบริเวณชั้น G สยามเซ็นเตอร์ คราคร่ำไปด้วยสาวๆ ที่แต่งตัวในธีมเดรสโค้ดสีดำ และเติมเรียวปากด้วยลิปสติกเฉดสีแดง ซึ่งเป็นลุคซิกเนเจอร์ของโปรเฟสชันนัลเมกอัพอาร์ทิสต์ชื่อดังของเกาหลี จองแซมมุล ผู้เชี่ยวชาญการแต่งหน้าเผยผิวสวยสุขภาพแบบ Glass Skin ที่บินตรงจากเกาหลี พาแบรนด์เครื่องสำอางสุดฮอตของเธอมาเปิดตัวที่เมืองไทย แต่ก่อนหน้านั้นหนึ่งวัน ...',
#   'DATE': '30-08-2019'},
#  {'title': 'ส่องเส้นทางชีวิตของ น้องฉัตร-ฉัตรชัย เพียงอภิชาติ จากเด็กอาชีวะสู่การเป็นช่างแต่งหน้า สะบัดฝีแปรงมหัศจรรย์ เมกอัพอาร์ทิสต์ชื่อดังแถวหน้าของเมืองไทย',
#   'detail': 'เส้นทางอาชีพของเหล่าช่างแต่งหน้าทำผมที่มีชื่อเสียงโด่งดังในบ้านเรา ล้วนมีที่มาแตกต่าง บางคนมีต้นทุนพร้อมตั้งแต่ฐานะครอบครัว การเงิน และแวดวงสังคมที่ส่งเสริมอาชีพจนได้มีชื่อเสียง แต่สำหรับช่างแต่งหน้าฝีมือระดับประเทศอย่าง น้องฉัตร-ฉัตรชัย เพียงอภิชาติ เขามีเส้นทางอาชีพที่น่าทึ่งและชวนให้ภาคภูมิใจอย่างมาก จากเด็กคนหนึ่งที่ตัดสินใจเข้าเรียนสายอาชีวะ เ...',
#   'DATE': '13-08-2019'},
#  {'title': 'ถอดรหัสพอร์ตการลงทุน (ชีวิต) ของ ‘สุขวัฒน์ ประเสริฐยิ่ง’ CIO ของ เอไอเอ ประเทศไทย ชายผู้เลือกสรรเฉพาะการลงทุนที่คุ้มเสี่ยง [Advertorial]',
#   'detail': 'ประโยคเชยๆ ที่ว่า ‘การลงทุนมีความเสี่ยง แต่การไม่ลงทุนเลยกลับเสี่ยงยิ่งกว่า’ เป็นสัจธรรมที่นักลงทุนทุกคนทราบกันดี แต่ใช่ว่านักลงทุนทุกคนจะกล้าลงทุนกับทุกเรื่องในชีวิต เว้นเสียแต่ว่าเขาผู้นั้นจะมีวิสัยทัศน์ต่างจากคนอื่น จึงมองเห็น ‘กำไร’ ที่คุ้มมากพอที่จะเสี่ยง\n\xa0\nเหมือนกับที่ สุขวัฒน์ ประเสริฐยิ่ง ประธานเจ้าหน้าที่ฝ่ายการลงทุน (Chief Inve...',
#   'DATE': '5-08-2019'},
#  {'title': 'ฟัลเกา จากผู้ล้มเหลวในสนามฟุตบอล สู่เปเลแห่งวงการฟุตซอล',
#   'detail': 'ตำนานเทพเจ้าราชันแห่งวงการฟุตซอล คือชื่อที่คุณจะได้พบเจอผูกติดอยู่กับชายที่มีชื่อว่า อเลสซานโดร โรซา วิเอรา หรือ ฟัลเกา ซึ่งเขาได้ประกาศเมื่อวันที่ 24 ตุลาคมที่ผ่าน ว่าถึงเวลาแล้วที่เขาลงสนามฟุตซอลเป็นครั้งสุดท้ายในฐานะนักเตะอาชีพให้กับทีมชาติบราซิลในวัย 41 ปี หลังจากการรับใช้ชาติกว่า 250 นัดตลอด 20 ปีที่ผ่านมา\n\xa0\n“ทุกอย่างที่ผ่านมามันได...',
#   'DATE': '26-10-2018'},
#  {'title': 'เอสซีจี เมืองทองฯ ประกาศยกเลิกสัญญา โค้ชแบน-ธชตวัน ศรีปาน หัวหน้าผู้ฝึกสอน',
#   'detail': 'สโมสรเอสซีจี เมืองทอง ยูไนเต็ด ได้ประกาศยกเลิกสัญญากับ โค้ชแบน-ธชตวัน ศรีปาน หัวหน้าผู้ฝึกสอน เป็นที่เรียบร้อย หลังจากทั้งสองฝ่ายเจรจาหารือร่วมกัน ก่อนจะนำไปสู่การตกลงยุติสัญญา ณ ที่ทำการของสโมสร\n\xa0\nโดยบอร์ดบริหารได้แถลงข้อความขอบคุณโค้ชแบนกับการทุ่มเททำงานอย่างหนัก และพาทีมประสบความสำเร็จตลอดมา\n\xa0\n“ในนามบอร์ดบริหารของสโมสร ต้อ...',
#   'DATE': '13-03-2018'},
#  {'title': 'ตำนานลูกหนัง จอร์จ เวอาห์ เตรียมครองเก้าอี้ประธานาธิบดีไลบีเรีย หลังชนะเลือกตั้งท่วมท้น',
#   'detail': 'จอร์จ เวอาห์ อดีตนักฟุตบอลระดับตำนานของสโมสรเอซี มิลาน และนักการเมืองจากพรรค Congress for Democratic Change ประเทศไลบีเรีย เตรียมขึ้นดำรงตำแหน่งประธานาธิบดีคนใหม่ของประเทศ หลังกวาดคะแนนชนะการเลือกตั้งอย่างไม่เป็นทางการเหนือคู่แข่งอย่าง โจเซฟ โบอาไค รองประธานาธิบดีคนปัจจุบันจากพรรค Unity\n\xa0\nเมื่อเวลาประมาณ 18.30 น. ของวันพฤหัสบดีที่ 28 ธัน...',
#   'DATE': '29-12-2017'},
#  {'title': 'เลฟ ยาชิน กับสัญลักษณ์ทางการเมืองผ่านโปสเตอร์ฟุตบอลโลก 2018',
#   'detail': 'ฟุตบอลโลกปี 2018 ที่ประเทศรัสเซียกำลังจะเริ่มขึ้นในวันที่ 14 มิถุนายน ปี 2018 นี้แล้ว โดยก่อนที่จะเริ่มต้นการจับฉลากแบ่งกลุ่มกันในช่วงค่ำของวันที่ 1 ธันวาคมนี้ ตามเวลาประเทศไทย ทางสหพันธ์ฟุตบอลนานาชาติ หรือ FIFA ได้ปล่อยโปสเตอร์โปรโมตการแข่งขันอย่างเป็นทางการออกมาให้แฟนบอลได้เห็นกัน\n\xa0\nฟุตบอลโลก\nโดยภาพโปสเตอร์ฟุตบอลโลกคราวนี้เป็นภาพของ...',
#   'DATE': '1-12-2017'}]

# %%
#df2 = pd.json_normalize(data)
#df2

# %% [markdown]
# ### NER (NameEntitiesRegcognition)
# * extract entity from news description

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

# %%
tokenizer = AutoTokenizer.from_pretrained("Davlan/xlm-roberta-base-ner-hrl")
model = AutoModelForTokenClassification.from_pretrained("Davlan/xlm-roberta-base-ner-hrl")
nlp = pipeline("ner", model=model, tokenizer=tokenizer)

# %%
example = "My name is Wolfgang and I live in Berlin"

ner_results = nlp(example)
print(ner_results)
# Out:
# [{'entity': 'B-PER', 'score': 0.9993357, 'index': 4, 'word': '▁Wolfgang', 'start': 10, 'end': 19}, {'entity': 'B-LOC', 'score': 0.9990395, 'index': 9, 'word': '▁Berlin', 'start': 33, 'end': 40}]

# %%
def post_process(preds):
    data = []
    for i in range(len(preds)): 
        a = preds[i]
        text = a.get('word')
        for j in range(i, len(preds)):
            b = preds[j]
            if b.get('start') == a.get('end'):
                text += b.get('word')
                a = b
        data.append({
            'type': a.get('entity'),
            'text': text
        })
    tmp = []
    for elm in data:
        text = elm.get('text')
        if bool(re.match("[ก-๛]|▁", text)):
            elm.update({'text': text.replace('▁', ' ')})
            tmp.append(elm)
    return tmp

# %%
text = data[0]['detail']
text
# Out:
# 'วันนี้ (3 ตุลาคม) \u202aเวลา 13.30 น. ณ โรงแรมมิราเคิล แกรนด์ กรุงเทพฯ พล.อ. ประยุทธ์ จันทร์โอชา นายกรัฐมนตรี และรัฐมนตรีว่าการกระทรวงกลาโหม เป็นประธานมอบนโยบายแก่สภาเกษตรกรแห่งชาติ ในโอกาสจัดประชุมสภาเกษตรกรแห่งชาติ ปีงบประมาณ 2563 พร้อมด้วย สมคิด จาตุศรีพิทักษ์ รองนายกรัฐมนตรี เฉลิมชัย ศรีอ่อน รัฐมนตรีว่าการกระทรวงเกษตรและสหกรณ์ สมาชิกสภาเกษตรกรแห่งชา...'

# %%
output = nlp(text)
output
# Out:
# [{'entity': 'B-ORG',
#   'score': 0.8451314,
#   'index': 12,
#   'word': 'มิ',
#   'start': 41,
#   'end': 43},
#  {'entity': 'I-ORG',
#   'score': 0.7218461,
#   'index': 13,
#   'word': 'รา',
#   'start': 43,
#   'end': 45},
#  {'entity': 'I-ORG',
#   'score': 0.7733644,
#   'index': 14,
#   'word': 'เค',
#   'start': 45,
#   'end': 47},
#  {'entity': 'I-ORG',
#   'score': 0.888565,
#   'index': 15,
#   'word': 'ิล',
#   'start': 47,
#   'end': 49},
#  {'entity': 'I-ORG',
#   'score': 0.9047262,
#   'index': 16,
#   'word': '▁',
#   'start': 49,
#   'end': 50},
#  {'entity': 'I-ORG',
#   'score': 0.89152133,
#   'index': 17,
#   'word': 'แกรนด์',
#   'start': 50,
#   'end': 56},
#  {'entity': 'I-LOC',
#   'score': 0.46179867,
#   'index': 18,
#   'word': '▁',
#   'start': 56,
#   'end': 57},
#  {'entity': 'B-LOC',
#   'score': 0.4928247,
#   'index': 19,
#   'word': 'กรุงเทพฯ',
#   'start': 57,
#   'end': 65},
#  {'entity': 'B-PER',
#   'score': 0.99985147,
#   'index': 25,
#   'word': '▁',
#   'start': 71,
#   'end': 72},
#  {'entity': 'B-PER',
#   'score': 0.9636953,
#   'index': 26,
#   'word': 'ประ',
#   'start': 72,
#   'end': 75},
#  {'entity': 'I-PER',
#   'score': 0.99956304,
#   'index': 27,
#   'word': 'ยุทธ',
#   'start': 75,
#   'end': 79},
#  {'entity': 'I-PER',
#   'score': 0.9994562,
#   'index': 28,
#   'word': '์',
#   'start': 79,
#   'end': 80},
#  {'entity': 'I-PER',
#   'score': 0.99982566,
#   'index': 29,
#   'word': '▁',
#   'start': 80,
#   'end': 81},
#  {'entity': 'I-PER',
#   'score': 0.9990067,
#   'index': 30,
#   'word': 'จันทร์',
#   'start': 81,
#   'end': 87},
#  {'entity': 'I-PER',
#   'score': 0.99980575,
#   'index': 31,
#   'word': 'โอ',
#   'start': 87,
#   'end': 89},
#  {'entity': 'I-PER',
#   'score': 0.9998497,
#   'index': 32,
#   'word': 'ชา',
#   'start': 89,
#   'end': 91},
#  {'entity': 'B-ORG',
#   'score': 0.8792407,
#   'index': 39,
#   'word': 'กระทรวง',
#   'start': 122,
#   'end': 129},
#  {'entity': 'I-ORG',
#   'score': 0.5603443,
#   'index': 40,
#   'word': 'ก',
#   'start': 129,
#   'end': 130},
#  {'entity': 'I-ORG',
#   'score': 0.99776304,
#   'index': 41,
#   'word': 'ลา',
#   'start': 130,
#   'end': 132},
#  {'entity': 'I-ORG',
#   'score': 0.99857736,
#   'index': 42,
#   'word': 'โห',
#   'start': 132,
#   'end': 134},
#  {'entity': 'I-ORG',
#   'score': 0.9973303,
#   'index': 43,
#   'word': 'ม',
#   'start': 134,
#   'end': 135},
#  {'entity': 'B-ORG',
#   'score': 0.9995049,
#   'index': 49,
#   'word': 'สภา',
#   'start': 158,
#   'end': 161},
#  {'entity': 'I-ORG',
#   'score': 0.9992513,
#   'index': 50,
#   'word': 'เกษตรกร',
#   'start': 161,
#   'end': 168},
#  {'entity': 'I-ORG',
#   'score': 0.99200916,
#   'index': 51,
#   'word': 'แห่งชาติ',
#   'start': 168,
#   'end': 176},
#  {'entity': 'B-ORG',
#   'score': 0.9207577,
#   'index': 56,
#   'word': 'สภา',
#   'start': 193,
#   'end': 196},
#  {'entity': 'I-ORG',
#   'score': 0.9465216,
#   'index': 57,
#   'word': 'เกษตรกร',
#   'start': 196,
#   'end': 203},
#  {'entity': 'B-PER',
#   'score': 0.9996025,
#   'index': 65,
#   'word': '▁',
#   'start': 237,
#   'end': 238},
#  {'entity': 'B-PER',
#   'score': 0.9982079,
#   'index': 66,
#   'word': 'สม',
#   'start': 238,
#   'end': 240},
#  {'entity': 'I-PER',
#   'score': 0.99907446,
#   'index': 67,
#   'word': 'คิด',
#   'start': 240,
#   'end': 243},
#  {'entity': 'I-PER',
#   'score': 0.9962691,
#   'index': 68,
#   'word': '▁',
#   'start': 243,
#   'end': 244},
#  {'entity': 'I-PER',
#   'score': 0.974957,
#   'index': 69,
#   'word': 'จา',
#   'start': 244,
#   'end': 246},
#  {'entity': 'I-PER',
#   'score': 0.99926144,
#   'index': 70,
#   'word': 'ตุ',
#   'start': 246,
#   'end': 248},
#  {'entity': 'I-PER',
#   'score': 0.9984316,
#   'index': 71,
#   'word': 'ศรี',
#   'start': 248,
#   'end': 251},
#  {'entity': 'I-PER',
#   'score': 0.99471384,
#   'index': 72,
#   'word': 'พิ',
#   'start': 251,
#   'end': 253},
#  {'entity': 'I-PER',
#   'score': 0.99934405,
#   'index': 73,
#   'word': 'ท',
#   'start': 253,
#   'end': 254},
#  {'entity': 'I-PER',
#   'score': 0.99900097,
#   'index': 74,
#   'word': 'ัก',
#   'start': 254,
#   'end': 256},
#  {'entity': 'I-PER',
#   'score': 0.99868995,
#   'index': 75,
#   'word': 'ษ',
#   'start': 256,
#   'end': 257},
#  {'entity': 'I-PER',
#   'score': 0.9940362,
#   'index': 76,
#   'word': '์',
#   'start': 257,
#   'end': 258},
#  {'entity': 'B-PER',
#   'score': 0.99965656,
#   'index': 79,
#   'word': '▁',
#   'start': 274,
#   'end': 275},
#  {'entity': 'B-PER',
#   'score': 0.99623907,
#   'index': 80,
#   'word': 'เฉลิม',
#   'start': 275,
#   'end': 280},
#  {'entity': 'I-PER',
#   'score': 0.99556005,
#   'index': 81,
#   'word': 'ชัย',
#   'start': 280,
#   'end': 283},
#  {'entity': 'I-PER',
#   'score': 0.9993383,
#   'index': 82,
#   'word': '▁',
#   'start': 283,
#   'end': 284},
#  {'entity': 'I-PER',
#   'score': 0.9977737,
#   'index': 83,
#   'word': 'ศรี',
#   'start': 284,
#   'end': 287},
#  {'entity': 'I-PER',
#   'score': 0.9997049,
#   'index': 84,
#   'word': 'อ่อน',
#   'start': 287,
#   'end': 291},
#  {'entity': 'B-ORG',
#   'score': 0.6009656,
#   'index': 90,
#   'word': 'เกษตร',
#   'start': 313,
#   'end': 318},
#  {'entity': 'I-ORG',
#   'score': 0.6458773,
#   'index': 91,
#   'word': 'และ',
#   'start': 318,
#   'end': 321},
#  {'entity': 'I-ORG',
#   'score': 0.61664295,
#   'index': 92,
#   'word': 'สหกรณ์',
#   'start': 321,
#   'end': 327},
#  {'entity': 'B-ORG',
#   'score': 0.9125547,
#   'index': 94,
#   'word': 'สภา',
#   'start': 334,
#   'end': 337},
#  {'entity': 'I-ORG',
#   'score': 0.74553597,
#   'index': 95,
#   'word': 'เกษตรกร',
#   'start': 337,
#   'end': 344}]

# %%
import re
post_process(output)
# Out:
# [{'type': 'B-LOC', 'text': 'มิราเคิล แกรนด์ กรุงเทพฯ'},
#  {'type': 'B-LOC', 'text': 'ราเคิล แกรนด์ กรุงเทพฯ'},
#  {'type': 'B-LOC', 'text': 'เคิล แกรนด์ กรุงเทพฯ'},
#  {'type': 'B-LOC', 'text': 'ิล แกรนด์ กรุงเทพฯ'},
#  {'type': 'B-LOC', 'text': ' แกรนด์ กรุงเทพฯ'},
#  {'type': 'B-LOC', 'text': 'แกรนด์ กรุงเทพฯ'},
#  {'type': 'B-LOC', 'text': ' กรุงเทพฯ'},
#  {'type': 'B-LOC', 'text': 'กรุงเทพฯ'},
#  {'type': 'I-PER', 'text': ' ประยุทธ์ จันทร์โอชา'},
#  {'type': 'I-PER', 'text': 'ประยุทธ์ จันทร์โอชา'},
#  {'type': 'I-PER', 'text': 'ยุทธ์ จันทร์โอชา'},
#  {'type': 'I-PER', 'text': '์ จันทร์โอชา'},
#  {'type': 'I-PER', 'text': ' จันทร์โอชา'},
#  {'type': 'I-PER', 'text': 'จันทร์โอชา'},
#  {'type': 'I-PER', 'text': 'โอชา'},
#  {'type': 'I-PER', 'text': 'ชา'},
#  {'type': 'I-ORG', 'text': 'กระทรวงกลาโหม'},
#  {'type': 'I-ORG', 'text': 'กลาโหม'},
#  {'type': 'I-ORG', 'text': 'ลาโหม'},
#  {'type': 'I-ORG', 'text': 'โหม'},
#  {'type': 'I-ORG', 'text': 'ม'},
#  {'type': 'I-ORG', 'text': 'สภาเกษตรกรแห่งชาติ'},
#  {'type': 'I-ORG', 'text': 'เกษตรกรแห่งชาติ'},
#  {'type': 'I-ORG', 'text': 'แห่งชาติ'},
#  {'type': 'I-ORG', 'text': 'สภาเกษตรกร'},
#  {'type': 'I-ORG', 'text': 'เกษตรกร'},
#  {'type': 'I-PER', 'text': ' สมคิด จาตุศรีพิทักษ์'},
#  {'type': 'I-PER', 'text': 'สมคิด จาตุศรีพิทักษ์'},
#  {'type': 'I-PER', 'text': 'คิด จาตุศรีพิทักษ์'},
#  {'type': 'I-PER', 'text': ' จาตุศรีพิทักษ์'},
#  {'type': 'I-PER', 'text': 'จาตุศรีพิทักษ์'},
#  {'type': 'I-PER', 'text': 'ตุศรีพิทักษ์'},
#  {'type': 'I-PER', 'text': 'ศรีพิทักษ์'},
#  {'type': 'I-PER', 'text': 'พิทักษ์'},
#  {'type': 'I-PER', 'text': 'ทักษ์'},
#  {'type': 'I-PER', 'text': 'ักษ์'},
#  {'type': 'I-PER', 'text': 'ษ์'},
#  {'type': 'I-PER', 'text': '์'},
#  {'type': 'I-PER', 'text': ' เฉลิมชัย ศรีอ่อน'},
#  {'type': 'I-PER', 'text': 'เฉลิมชัย ศรีอ่อน'},
#  {'type': 'I-PER', 'text': 'ชัย ศรีอ่อน'},
#  {'type': 'I-PER', 'text': ' ศรีอ่อน'},
#  {'type': 'I-PER', 'text': 'ศรีอ่อน'},
#  {'type': 'I-PER', 'text': 'อ่อน'},
#  {'type': 'I-ORG', 'text': 'เกษตรและสหกรณ์'},
#  {'type': 'I-ORG', 'text': 'และสหกรณ์'},
#  {'type': 'I-ORG', 'text': 'สหกรณ์'},
#  {'type': 'I-ORG', 'text': 'สภาเกษตรกร'},
#  {'type': 'I-ORG', 'text': 'เกษตรกร'}]

# %% [markdown]
# ## Process news to spo

# %%
spo = []
for news in tqdm(data):
    description = news.get('detail') 
    if description == None:
        continue
    ner = nlp(description)
    processed = post_process(ner)
    for kw in processed:
        spo.append({
            'Subject': news.get('title', ""),
            'Predicate': kw.get('type', ""),
            'Object': kw.get('text', ""),
            'Date' : news.get('DATE',""),
            'Detail' : news.get('detail',"")
        })
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]

# %%
df = pd.DataFrame(spo)
df['Predicate'] = df['Predicate'].apply(lambda x: x[2:])
df['Date'] = pd.to_datetime(df['Date'],errors='ignore',infer_datetime_format=True,yearfirst=True,exact=True)
df
# Out:
# /opt/conda/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /opt/conda/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /opt/conda/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /opt/conda/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /opt/conda/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '30-08-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /opt/conda/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13-08-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /opt/conda/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /opt/conda/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /opt/conda/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '29-12-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#                                                Subject Predicate  \
# 0    นายกฯ ขอให้ทุกคนรักชาติ มีศรัทธาในการทำงาน เกษ...       LOC
# 1    นายกฯ ขอให้ทุกคนรักชาติ มีศรัทธาในการทำงาน เกษ...       LOC
# 2    นายกฯ ขอให้ทุกคนรักชาติ มีศรัทธาในการทำงาน เกษ...       LOC
# 3    นายกฯ ขอให้ทุกคนรักชาติ มีศรัทธาในการทำงาน เกษ...       LOC
# 4    นายกฯ ขอให้ทุกคนรักชาติ มีศรัทธาในการทำงาน เกษ...       LOC
# ..                                                 ...       ...
# 273  เลฟ ยาชิน กับสัญลักษณ์ทางการเมืองผ่านโปสเตอร์ฟ...       ORG
# 274  เลฟ ยาชิน กับสัญลักษณ์ทางการเมืองผ่านโปสเตอร์ฟ...       ORG
# 275  เลฟ ยาชิน กับสัญลักษณ์ทางการเมืองผ่านโปสเตอร์ฟ...       ORG
# 276  เลฟ ยาชิน กับสัญลักษณ์ทางการเมืองผ่านโปสเตอร์ฟ...       ORG
# 277  เลฟ ยาชิน กับสัญลักษณ์ทางการเมืองผ่านโปสเตอร์ฟ...       ORG
#
#                        Object       Date  \
# 0    มิราเคิล แกรนด์ กรุงเทพฯ 2019-03-10
# 1      ราเคิล แกรนด์ กรุงเทพฯ 2019-03-10
# 2        เคิล แกรนด์ กรุงเทพฯ 2019-03-10
# 3          ิล แกรนด์ กรุงเทพฯ 2019-03-10
# 4             แกรนด์ กรุงเทพฯ 2019-03-10
# ..                        ...        ...
# 273     สหพันธ์ฟุตบอลนานาชาติ 2017-01-12
# 274       พันธ์ฟุตบอลนานาชาติ 2017-01-12
# 275            ฟุตบอลนานาชาติ 2017-01-12
# 276                  นานาชาติ 2017-01-12
# 277                      FIFA 2017-01-12
#
#                                                 Detail
# 0    วันนี้ (3 ตุลาคม) ‪เวลา 13.30 น. ณ โรงแรมมิราเ...
# 1    วันนี้ (3 ตุลาคม) ‪เวลา 13.30 น. ณ โรงแรมมิราเ...
# 2    วันนี้ (3 ตุลาคม) ‪เวลา 13.30 น. ณ โรงแรมมิราเ...
# 3    วันนี้ (3 ตุลาคม) ‪เวลา 13.30 น. ณ โรงแรมมิราเ...
# 4    วันนี้ (3 ตุลาคม) ‪เวลา 13.30 น. ณ โรงแรมมิราเ...
# ..                                                 ...
# 273  ฟุตบอลโลกปี 2018 ที่ประเทศรัสเซียกำลังจะเริ่มข...
# 274  ฟุตบอลโลกปี 2018 ที่ประเทศรัสเซียกำลังจะเริ่มข...
# 275  ฟุตบอลโลกปี 2018 ที่ประเทศรัสเซียกำลังจะเริ่มข...
# 276  ฟุตบอลโลกปี 2018 ที่ประเทศรัสเซียกำลังจะเริ่มข...
# 277  ฟุตบอลโลกปี 2018 ที่ประเทศรัสเซียกำลังจะเริ่มข...
#
# [278 rows x 5 columns]

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write(df=df, directory=dir_process_id, name="news_about_success2", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='news.json')])
# Out:
# {'sucess': True,
#  'file_id': 303,
#  'path': 'natthakan/DSI310-05/processData/news_about_success2.parquet',
#  'lineage': True}
